# %% [markdown]
# <a href="https://colab.research.google.com/github/16pynkn/MSC_DPDM_2025/blob/main/Data101_(dpdm25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data101_(Chapter2)

# %% [markdown]
# **pandas** คือ package ที่มีคนพัฒนาขึ้นมาเพื่อใช้จัดการข้อมูลที่มีลักษณะเป็นตาราง ซึ่งใน pandas เรียกว่า DataFrame
#
# **pandas** is a package for manage table data. pandas data structure for table is DataFrame

# %%
import pandas #import pandas คือ โหลด package มีชื่อว่า pandas มาใช้ (We use import to pandas define a package that we are using)

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# `({'A':[1,2,3],'B':[2,3,4]})`
# <br>
# Column: A, B
# <br>
# ค่าที่อยู่ใน column A: 1,2,3
# <br>
# ค่าที่อยู่ใน column B: 2,3,4

# %%
import pandas as pd # โหลด pandas package แล้วตั้งชื่อให้ว่า pd แทน (import pakage and name it as ...)

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# ไฟล์ .CSV (csv => comma separated values)
# - ใช้เครื่องหมาย comma ในการแบ่ง(คั่น)แต่ละ Columns
# - ขึ้น record ใหม่จะใช้การ Enter
#
# CSV File (csv => comma separated values)
# - use comma (,) to separate values
# - use new line (enter,\n) to separate data points

# %% [markdown]
# # Load data แบบ one-time-use

# %% [markdown]
# 2025-01-warwickshire-stop-and-search: ข้อมูลตำรวจที่ตรวจค้นคน

# %%
pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                          False                 NaN       NaN        NaN
# 1                          False                 NaN       NaN        NaN
# ...

# %%
SS_df = pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')

# %%
SS_df.shape # ดูหน้าของตาราง จำนวนแถว = 94 / จำนวนหลัก = 15
# Out:
# (94, 15)

# %%
SS_df.head(1)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T02:16:00+00:00                         False
#
#    Policing operation  Latitude  Longitude  Gender Age range  \
# 0                 NaN       NaN        NaN  Female     18-24
#
#                               Self-defined ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#   Outcome  Outcome linked to object of search  \
# 0  Arrest                                True
#
#    Removal of more than just outer clothing
# 0                                     False

# %%
SS_df.head() #ตาราง 5 แถวแรก
# Out:
#                         Type                       Date  \
# 0              Person search  2025-01-01T02:16:00+00:00
# 1              Person search  2025-01-01T23:21:00+00:00
# 2  Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3              Person search  2025-01-01T23:35:00+00:00
# 4              Person search  2025-01-01T23:45:00+00:00
#
#    Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                         False                 NaN       NaN        NaN
# 1                         False                 NaN       NaN        NaN
# 2                         False                 NaN       NaN        NaN
# 3                         False                 NaN       NaN        NaN
# 4                         False                 NaN       NaN        NaN
#
#    Gender Age range                             Self-defined ethnicity  \
# 0  Female     18-24  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
SS_df.head(7)
# Out:
#                         Type                       Date  \
# 0              Person search  2025-01-01T02:16:00+00:00
# 1              Person search  2025-01-01T23:21:00+00:00
# 2  Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3              Person search  2025-01-01T23:35:00+00:00
# 4              Person search  2025-01-01T23:45:00+00:00
# 5              Person search  2025-01-02T10:30:00+00:00
# 6              Person search  2025-01-02T14:25:00+00:00
#
#    Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                         False                 NaN       NaN        NaN
# 1                         False                 NaN       NaN        NaN
# 2                         False                 NaN       NaN        NaN
# 3                         False                 NaN       NaN        NaN
# 4                         False                 NaN       NaN        NaN
# 5                         False                 NaN       NaN        NaN
# ...

# %%
SS_df.tail() #ตาราง 5 แถวสุดท้าย
# Out:
#                          Type                       Date  \
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 89                         False                 NaN       NaN        NaN
# 90                         False                 NaN       NaN        NaN
# 91                         False                 NaN       NaN        NaN
# 92                         False                 NaN       NaN        NaN
# 93                         False                 NaN       NaN        NaN
#
#     Gender Age range                             Self-defined ethnicity  \
# 89    Male     25-34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %% [markdown]
# # Load data แบบ ถาวร (ผูกกับ Google drive)

# %%
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-01/2025-01-cambridgeshire-stop-and-search.csv')
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T17:30:00+00:00
# 1                Person search  2025-01-02T00:28:00+00:00
# 2                Person search  2025-01-02T00:38:00+00:00
# 3                Person search  2025-01-02T14:00:00+00:00
# 4    Person and Vehicle search  2025-01-02T16:50:00+00:00
# ..                         ...                        ...
# 219              Person search  2025-01-31T19:45:00+00:00
# 220  Person and Vehicle search  2025-01-31T20:11:00+00:00
# 221  Person and Vehicle search  2025-01-31T23:30:00+00:00
# 222              Person search  2025-01-31T23:40:00+00:00
# 223              Person search  2025-01-31T23:45:00+00:00
#
#     Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                            NaN                 NaN  52.221213  -0.297510
# 1                            NaN                 NaN  52.572933  -0.241374
# ...

# %%
pd.read_csv('/content/2025-01-avon-and-somerset-stop-and-search.csv')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                  avon_stop_and_search
# Type                      Date                      Part of a policing operation Policing operation Latitude  Longitude Gender Age range Self-defined ethnicity                             Officer-defined ethnicity Legislation                           Object of search Outcome                      Outcome linked to object of search  Removal of more than just outer clothing
# ...

# %%
pd.read_csv('/content/2025-01-avon-and-somerset-stop-and-search.csv', skiprows=1)
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T01:49:14+00:00
# 1    Person and Vehicle search  2025-01-01T01:49:14+00:00
# 2                Person search  2025-01-01T02:09:24+00:00
# 3                Person search  2025-01-01T02:09:24+00:00
# 4                Person search  2025-01-01T02:09:24+00:00
# ..                         ...                        ...
# 560              Person search  2025-01-31T18:58:50+00:00
# 561              Person search  2025-01-31T18:58:50+00:00
# 562  Person and Vehicle search  2025-01-31T19:14:19+00:00
# 563  Person and Vehicle search  2025-01-31T19:14:19+00:00
# 564  Person and Vehicle search  2025-01-31T19:14:19+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN  51.491668  -2.492035
# 1                             NaN                 NaN  51.491668  -2.492035
# ...

# %% [markdown]
# ## Homework 6 ดึงตาราง
# ผลงานตีพิมพ์ที่เกี่ยวข้อในฐาน ข้อมูล SCOPUS โดยไม่เอาตัวอย่าง จากไฟล์ `การตีพิมพ์เผยแพร่ในวารสารที่อยู่ในฐาน` SCOPUS-.xlsx
#
#
#
# *   ส่ง 21 ก.ค. 2025

# %%
import pandas as pd

# %%
pd.read_excel('/content/การตีพิมพ์เผยแพร่ในวารสารที่อยู่ในฐาน SCOPUS-.xlsx')
# Out:
#                                            Unnamed: 0  \
# 0                ทุนส่งเสริมการเพิ่มจํานวนทุนการศึ...
# 1                             (ภายใต้โครงการส่งเสร...
# 2   มีผลงานตีพิมพ์ที่เกี่ยวข้องในฐานข้อมูล SCOPUS ...
# 3   ชื่อ-สกุล ดร.ธนพงศ์ นามสกุล อินทระ อาจารย์ประจ...
# 4                        อาจารย์สังกัดคณะ วิทยาศาสตร์
# 5                                                 No.
# 6                                            ตัวอย่าง
# 7                                                   1
# 8                                                   2
# 9                                                   3
# 10                                                  4
# 11                                                  5
# 12                                                  6
# 13                                                  7
# 14                                                  8
# 15                                                  9
# ...

# %%
df = pd.read_excel('/content/การตีพิมพ์เผยแพร่ในวารสารที่อยู่ในฐาน SCOPUS-.xlsx', skiprows=6)
df
# Out:
#          No.                                            Authors  \
# 0   ตัวอย่าง  Ngeontae, Wittaya; Chaiendoo, Kanokwan; Ngamde...
# 1          1  Wiratchawa, Kannika; Wanna, Yupaporn; Junsawan...
# 2          2  Jarujareet, Ungkarn; Wiratchawa, Kannika; Peti...
# 3          3  Petiwathayakorn, Touchwin; Paradee, Narisara; ...
# 4          4  Srisomboon, Surapong; Intharah, Thanapong; Jar...
# 5          5  Penpong, Nutsuda; Wanna, Yupaporn; Kamjanlard,...
# 6          6               Wanna, Yupaporn; Intharah, Thanapong
# 7          7  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 8          8  Panphet, Natchaya; Junpeng, Putcharee; Inthara...
# 9          9  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 10        10  Paenpa, Phenjarat; Junpeng, Putcbaree; Inthara...
# 11        11  Wiratchawa, Kannika; Petiwathayakorn, Touchwin...
# 12        12  Hirunchavarod, Natthanich; Phuphatham, Pornnak...
# 13        13  Hirunchavarod, Natthanich; Dangsungnoen, Lapat...
# ...

# %%
df.drop(0)
# Out:
#    No.                                            Authors  \
# 1    1  Wiratchawa, Kannika; Wanna, Yupaporn; Junsawan...
# 2    2  Jarujareet, Ungkarn; Wiratchawa, Kannika; Peti...
# 3    3  Petiwathayakorn, Touchwin; Paradee, Narisara; ...
# 4    4  Srisomboon, Surapong; Intharah, Thanapong; Jar...
# 5    5  Penpong, Nutsuda; Wanna, Yupaporn; Kamjanlard,...
# 6    6               Wanna, Yupaporn; Intharah, Thanapong
# 7    7  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 8    8  Panphet, Natchaya; Junpeng, Putcharee; Inthara...
# 9    9  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 10  10  Paenpa, Phenjarat; Junpeng, Putcbaree; Inthara...
# 11  11  Wiratchawa, Kannika; Petiwathayakorn, Touchwin...
# 12  12  Hirunchavarod, Natthanich; Phuphatham, Pornnak...
# 13  13  Hirunchavarod, Natthanich; Dangsungnoen, Lapat...
# 14  14  Thonghlueng, Janpen; Ngernpimai, Sawinee; Chua...
# 15  15  Intharah, Thanapong; Wiratchawa, Kannika; Wann...
# ...

# %% [markdown]
# #Pre-Processing

# %%
import pandas as pd

SS_warwick = pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
SS_warwick = pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')
#display(SS_warwick.head())

# %% [markdown]
# ###  ตรวจสอบ missing ```isnull()```

# %%
SS_warwick.isnull()
# Out:
#      Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0   False  False                         False                True      True
# 1   False  False                         False                True      True
# 2   False  False                         False                True      True
# 3   False  False                         False                True      True
# 4   False  False                         False                True      True
# ..    ...    ...                           ...                 ...       ...
# 89  False  False                         False                True      True
# 90  False  False                         False                True      True
# 91  False  False                         False                True      True
# 92  False  False                         False                True      True
# 93  False  False                         False                True      True
#
# ...

# %%
SS_warwick.isnull().any() # เอาค่าความจริงทุกค่าความจริงมา or กัน
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                      False
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                  True
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# *   NA
# *   NaN
# *   null
# *   None

# %% [markdown]
# # Query Rows
# ใช้ list ของ logic ที่มีขนาดความยาวเท่ากับขนาดของ row ของตารางนั้น

# %%
SS_warwick.isnull()['Officer-defined ethnicity']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 89    False
# 90    False
# 91    False
# 92    False
# 93    False
# Name: Officer-defined ethnicity, Length: 94, dtype: bool

# %%
SS_warwick[SS_warwick.isnull()['Officer-defined ethnicity']] #ค่าในOfficer-defined ethnicityเป็น NaN ดูว่าค่าผิดปกติยังไง
# Out:
#                          Type                       Date  \
# 11              Person search  2025-01-03T14:30:00+00:00
# 30              Person search  2025-01-12T05:12:00+00:00
# 31  Person and Vehicle search  2025-01-12T18:19:00+00:00
# 32  Person and Vehicle search  2025-01-12T18:37:00+00:00
# 60              Person search  2025-01-20T01:45:00+00:00
# 61              Person search  2025-01-20T01:45:00+00:00
# 69              Person search  2025-01-23T16:19:00+00:00
# 82              Person search  2025-01-29T15:34:00+00:00
# 83  Person and Vehicle search  2025-01-29T15:37:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 11                         False                 NaN       NaN        NaN
# 30                         False                 NaN       NaN        NaN
# 31                         False                 NaN       NaN        NaN
# 32                         False                 NaN       NaN        NaN
# ...

# %% [markdown]
# # Quiz 6
# แสดง row ทั้งหมดที่ผู้ต้องสงสัย มี Age ระหว่าง 10-17 ปี

# %%
SS_warwick['Age range'] == '10-17'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 89    False
# 90    False
# 91     True
# 92     True
# 93     True
# Name: Age range, Length: 94, dtype: bool

# %%
SS_warwick[SS_warwick['Age range'] == '10-17']
# Out:
#              Type                       Date  Part of a policing operation  \
# 10  Person search  2025-01-03T14:00:00+00:00                         False
# 11  Person search  2025-01-03T14:30:00+00:00                         False
# 12  Person search  2025-01-03T19:20:00+00:00                         False
# 13  Person search  2025-01-04T01:05:00+00:00                         False
# 16  Person search  2025-01-06T16:11:00+00:00                         False
# 17  Person search  2025-01-06T17:25:00+00:00                         False
# 26  Person search  2025-01-09T17:39:00+00:00                         False
# 41  Person search  2025-01-14T20:44:00+00:00                         False
# 48  Person search  2025-01-16T16:04:00+00:00                         False
# 51  Person search  2025-01-17T22:00:00+00:00                         False
# 60  Person search  2025-01-20T01:45:00+00:00                         False
# ...

# %%
len(SS_warwick[SS_warwick['Age range'] == '10-17'])
# Out:
# 21

# %% [markdown]
# #การใช้ `groupby`
# ![GROUPBY.png](data:image/png;base64,...)

# %% [markdown]
# # เด็กเชื้อชาติไหน ถูกเรียกค้น เยอะที่สุด

# %%
SS_warwick[SS_warwick['Age range'] == '10-17'].groupby('Self-defined ethnicity').count()
# Out:
#                                                     Type  Date  \
# Self-defined ethnicity
# Asian/Asian British - Indian                           1     1
# Other ethnic group - Not stated                        2     2
# White - Any other White background                     1     1
# White - English/Welsh/Scottish/Northern Irish/B...    17    17
#
#                                                     Part of a policing operation  \
# Self-defined ethnicity
# Asian/Asian British - Indian                                                   1
# Other ethnic group - Not stated                                                2
# White - Any other White background                                             1
# White - English/Welsh/Scottish/Northern Irish/B...                            17
#
#                                                     Policing operation  \
# Self-defined ethnicity
# Asian/Asian British - Indian                                         0
# ...

# %% [markdown]
# #เด็กแต่ละเชื้อชาติ ถูกเรียกค้น โดยตำรวจเชื้อชาติใดบ้าง

# %%
SS_warwick[SS_warwick['Age range'] == '10-17'].groupby(['Self-defined ethnicity'
                                            ,'Officer-defined ethnicity']).count()
# Out:
#                                                                               Type  \
# Self-defined ethnicity                             Officer-defined ethnicity
# Asian/Asian British - Indian                       Asian                         1
# Other ethnic group - Not stated                    White                         2
# White - Any other White background                 White                         1
# White - English/Welsh/Scottish/Northern Irish/B... White                        13
#
#                                                                               Date  \
# Self-defined ethnicity                             Officer-defined ethnicity
# Asian/Asian British - Indian                       Asian                         1
# Other ethnic group - Not stated                    White                         2
# White - Any other White background                 White                         1
# ...

# %% [markdown]
# # Quiz 7 เปรียบเทียบตำรวจที่เป็น White และ Black ชอบเรียกค้นคนอายุเท่าไหร่ และเชื้อชาติไหน ต่างกันอย่างไร

# %%
# Filter for White officers
white_officer_stops = SS_warwick[SS_warwick['Officer-defined ethnicity'] == 'White']

# Group by Age range and Self-defined ethnicity for White officers
white_officer_analysis = white_officer_stops.groupby(['Age range', 'Self-defined ethnicity']).size().reset_index(name='count')
print("Stops by White Officers:")
display(white_officer_analysis)

# Filter for Black officers
black_officer_stops = SS_warwick[SS_warwick['Officer-defined ethnicity'] == 'Black']

# Group by Age range and Self-defined ethnicity for Black officers
black_officer_analysis = black_officer_stops.groupby(['Age range', 'Self-defined ethnicity']).size().reset_index(name='count')
print("\nStops by Black Officers:")
display(black_officer_analysis)
# Out:
# Stops by White Officers:
#   Age range                             Self-defined ethnicity  count
# 0     10-17                    Other ethnic group - Not stated      2
# 1     10-17                 White - Any other White background      1
# 2     10-17  White - English/Welsh/Scottish/Northern Irish/...     13
# 3     18-24                 White - Any other White background      2
# 4     18-24  White - English/Welsh/Scottish/Northern Irish/...      8
# 5     25-34                 White - Any other White background      1
# 6     25-34  White - English/Welsh/Scottish/Northern Irish/...      6
# 7   over 34                    Other ethnic group - Not stated      2
# 8   over 34                 White - Any other White background      4
# 9   over 34  White - English/Welsh/Scottish/Northern Irish/...     15
# Stops by Black Officers:
#   Age range                             Self-defined ethnicity  count
# 0     18-24  Black/African/Caribbean/Black British - Any ot...      1
# ...

# %% [markdown]
# ตำรวจผิวขาวมีแนวโน้มที่จะเรียกตรวจค้นบุคคลในกลุ่ม White - English/Welsh/Scottish/Northern Irish/... ในทุกช่วงอายุ แต่มีการเรียกตรวจค้นกลุ่มอายุ 10-17 ปี และ over 34 ปี มากที่สุด

# %% [markdown]
# ตำรวจผิวดำมีจำนวนการเรียกตรวจค้นที่ค่อนข้างน้อยเมื่อเทียบกับตำรวจผิวขาว และมีการเรียกตรวจค้นหลากหลายเชื้อชาติ แต่มีแนวโน้มที่จะเรียกตรวจค้นกลุ่มคนผิวสีในบางช่วงอายุ

# %% [markdown]
# # missing data handling

# %% [markdown]
# ## 1 ลบทิ้ง ```dropna()```

# %%
import pandas as pd

# %%
SS_warwick = pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')

# %%
SS_warwick
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                          False                 NaN       NaN        NaN
# 1                          False                 NaN       NaN        NaN
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
SS_warwick = pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')
display(SS_warwick.head())
# Out:
#                         Type                       Date  \
# 0              Person search  2025-01-01T02:16:00+00:00
# 1              Person search  2025-01-01T23:21:00+00:00
# 2  Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3              Person search  2025-01-01T23:35:00+00:00
# 4              Person search  2025-01-01T23:45:00+00:00
#
#    Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                         False                 NaN       NaN        NaN
# 1                         False                 NaN       NaN        NaN
# 2                         False                 NaN       NaN        NaN
# 3                         False                 NaN       NaN        NaN
# 4                         False                 NaN       NaN        NaN
#
#    Gender Age range                             Self-defined ethnicity  \
# 0  Female     18-24  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
SS_warwick.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %% [markdown]
# ###1.1 Drop เฉพาะ column  ที่มีค่า missing มากกว่า 50%

# %%
# Calculate the percentage of missing values for each column
missing_percentage = SS_warwick.isnull().sum() / len(SS_warwick) * 100

# Identify columns with more than 50% missing values
columns_to_drop = missing_percentage[missing_percentage > 50].index

# Drop the identified columns
SS_warwick_dropped = SS_warwick.drop(columns=columns_to_drop)

# Display the first few rows of the modified DataFrame
display(SS_warwick_dropped.head())
# Out:
#                         Type                       Date  \
# 0              Person search  2025-01-01T02:16:00+00:00
# 1              Person search  2025-01-01T23:21:00+00:00
# 2  Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3              Person search  2025-01-01T23:35:00+00:00
# 4              Person search  2025-01-01T23:45:00+00:00
#
#    Part of a policing operation  Gender Age range  \
# 0                         False  Female     18-24
# 1                         False    Male     18-24
# 2                         False    Male       NaN
# 3                         False    Male     18-24
# 4                         False    Male     18-24
#
#                               Self-defined ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...
# 1                    Asian/Asian British - Pakistani
# 2    Black/African/Caribbean/Black British - African
# 3                    Asian/Asian British - Pakistani
# ...

# %%
SS_warwick_dropped.dropna()
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# 6               Person search  2025-01-02T14:25:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Gender Age range  \
# 0                          False  Female     18-24
# 1                          False    Male     18-24
# 3                          False    Male     18-24
# 4                          False    Male     18-24
# ...

# %% [markdown]
# ### 1.2 Drop เฉพาะ Data ที่มี Missing ใน Colunm ที่เราสนใจ

# %%
SS_warwick.dropna(subset=['Date','Gender','Age range','Self-defined ethnicity','Officer-defined ethnicity','Object of search'])
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# 5               Person search  2025-01-02T10:30:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                          False                 NaN       NaN        NaN
# 1                          False                 NaN       NaN        NaN
# ...

# %% [markdown]
# ## 2 เติมค่า missing `fillna()`

# %% [markdown]
# ## 2.1 เติมค่าด้วย dummy value (ซึ่งต้องเป็นตัวเลขที่ไม่มีอยู่ในข้อมูล เพื่อสื่อว่าเป็น ค่า missing)

# %%
set(SS_warwick['Part of a policing operation'])
# Out:
# {False, True}

# %%
SS_warwick.fillna({'Part of a policing operation':False})
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                          False                 NaN       NaN        NaN
# 1                          False                 NaN       NaN        NaN
# ...

# %%
SS_warwick.fillna({'Part of a policing operation':False}, inplace=True)

# %% [markdown]
# ## 2.2เติม missing ด้วยค่ากลาง

# %% [markdown]
# เติม Latitude และ Longtitude ด้วยค่าเฉลี่ย (Mean)

# %%
SS_warwick.fillna({'Part of a policing operation':False,
                   'Latitude':SS_warwick['Latitude'].mean(),
                   'Longitude':SS_warwick['Longitude'].mean()
                   })
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                          False                 NaN       NaN        NaN
# 1                          False                 NaN       NaN        NaN
# ...

# %%
SS_warwick2 = pd.read_csv('/content/2025-02-warwickshire-stop-and-search.csv')

# %%
SS_warwick2.isnull().all()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
SS_london = pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-01/2025-01-city-of-london-stop-and-search.csv')

# %%
SS_london = pd.read_csv('/content/2025-01-city-of-london-stop-and-search.csv')

# %%
SS_london
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1    Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2    Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3    Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4                Person search  2025-01-02T03:19:44+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN        NaN        NaN
# ...

# %%
SS_london.isnull().all()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                 True
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# ## ตรวจสอบความสัมพันธ์

# %%
SS_london.groupby(['Self-defined ethnicity','Age range']).count()
# Out:
#                                                               Type  Date  \
# Self-defined ethnicity                             Age range
# Asian/Asian British - Any other Asian background   10-17         1     1
#                                                    18-24         1     1
#                                                    25-34         3     3
# Asian/Asian British - Bangladeshi                  18-24         2     2
#                                                    25-34         4     4
# Asian/Asian British - Indian                       25-34         1     1
# Asian/Asian British - Pakistani                    25-34         3     3
#                                                    over 34       3     3
# Black/African/Caribbean/Black British - African    10-17         1     1
#                                                    18-24         2     2
#                                                    25-34         5     5
# ...

# %% [markdown]
# # HW7 ตรวจสอบความสัมพันธ์ แล้วเติมด้วยค่าของ Same Class

# %%
SS_london.groupby(['Self-defined ethnicity','Age range'])['Type'].count()
# Out:
# Self-defined ethnicity                                                                Age range
# Asian/Asian British - Any other Asian background                                      10-17         1
#                                                                                       18-24         1
#                                                                                       25-34         3
# Asian/Asian British - Bangladeshi                                                     18-24         2
#                                                                                       25-34         4
# Asian/Asian British - Indian                                                          25-34         1
# Asian/Asian British - Pakistani                                                       25-34         3
#                                                                                       over 34       3
# ...

# %%
mode_by_self = SS_london.groupby('Self-defined ethnicity')['Age range'].transform(lambda x: x.mode()[0])

# %%
SS_london['Age range'] = SS_london['Age range'].fillna(mode_by_self)

# %%
SS_london.groupby(['Self-defined ethnicity','Age range'])['Type'].count()
# Out:
# Self-defined ethnicity                                                                Age range
# Asian/Asian British - Any other Asian background                                      10-17         1
#                                                                                       18-24         1
#                                                                                       25-34         3
# Asian/Asian British - Bangladeshi                                                     18-24         2
#                                                                                       25-34         4
# Asian/Asian British - Indian                                                          25-34         1
# Asian/Asian British - Pakistani                                                       25-34         3
#                                                                                       over 34       3
# ...

# %% [markdown]
# # Outlier Detection

# %%
SS_london
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1    Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2    Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3    Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4                Person search  2025-01-02T03:19:44+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN        NaN        NaN
# ...

# %%
 SS_london[~SS_london['Longitude'].isnull()] #Longitude ที่ไม่มี missing
# Out:
#                           Type                       Date  \
# 4                Person search  2025-01-02T03:19:44+00:00
# 5    Person and Vehicle search  2025-01-02T03:23:13+00:00
# 6                Person search  2025-01-02T17:38:36+00:00
# 8                Person search  2025-01-02T21:56:33+00:00
# 9                Person search  2025-01-03T13:28:06+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 4                             NaN                 NaN  51.510042  -0.120439
# 5                             NaN                 NaN  51.510042  -0.120439
# ...

# %% [markdown]
# ## box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(SS_london['Longitude']) #มี Noise
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x786215d0dac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x786215d0fe00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x786215d0f650>],
#  'medians': [<matplotlib.lines.Line2D at 0x786215970410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x786215970710>],
#  'means': []}

# %%
plt.boxplot(SS_london['Longitude'].dropna()) # Corrected code to plot non-null longitude values
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7862159b9850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7862159b9f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7862159b9520>],
#  'medians': [<matplotlib.lines.Line2D at 0x7862159ba540>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7862159ba870>],
#  'means': []}

# %%
bp1 = plt.boxplot(SS_london[~SS_london['Longitude'].isnull()]['Longitude'], whis=0.8,
            vert=False)
bp1
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x786213724440>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x786213724aa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7862159ffef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x786213724fb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7862137252e0>],
#  'means': []}

# %%
bp1['fliers']

# %%
bp1['fliers'][0]

# %%
bp1['fliers'][0].get_xdata()
# Out:
# array([-0.120439, -0.120439, -0.112953, -0.068095, -0.061248, -0.061248,
#        -0.061248, -0.065495])

# %%
bp1['whiskers'] #มีสองฝั่ง [0] left, [1] right

# %%
bp1['whiskers'][0].get_xdata()[1]
# Out:
# np.float64(-0.108894)

# %%
bp1['whiskers'][1].get_xdata()[1]
# Out:
# np.float64(-0.072148)

# %%
outlier_ld = SS_london[(SS_london['Longitude'] > bp1['whiskers'][0].get_xdata()[1])& (SS_london['Longitude'] < bp1['whiskers'][1].get_xdata()[1])]

# %%
outlier_ld
# Out:
#                           Type                       Date  \
# 8                Person search  2025-01-02T21:56:33+00:00
# 9                Person search  2025-01-03T13:28:06+00:00
# 13               Person search  2025-01-03T21:13:46+00:00
# 14   Person and Vehicle search  2025-01-03T21:34:15+00:00
# 18   Person and Vehicle search  2025-01-04T03:48:28+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 8                             NaN                 NaN  51.514770  -0.101292
# 9                             NaN                 NaN  51.513736  -0.095224
# ...

# %%
outlier_ld[outlier_ld['Longitude']> bp1['whiskers'][1].get_xdata()[1]]
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %%
plt.boxplot(outlier_ld['Longitude'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x786212b9e180>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x786212b9e6f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x786212b7d310>],
#  'medians': [<matplotlib.lines.Line2D at 0x786212b9ecc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x786212b9efc0>],
#  'means': []}

# %% [markdown]
# #Data Integration

# %% [markdown]
# เอา Data จากหลายๆตารางมารวมกัน
#
#
# 1.   แนวตั้ง (Column) เพิ่มตัวแปร
# 2.   แนวนอน (Row) เพิ่มข้อมูล (ขนาดข้อมูลเพิ่ม)

# %% [markdown]
# ## เพิ่มแกน Y (เพิ่ม Rows - เพิ่มปริมาณของข้อมูล)

# %%
SS_london01 = pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-01/2025-01-city-of-london-stop-and-search.csv')

# %%
SS_london02 = pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-02/2025-02-city-of-london-stop-and-search.csv')

# %%
SS_london03 = pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-03/2025-03-city-of-london-stop-and-search.csv')

# %%
SS_london01
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1    Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2    Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3    Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4                Person search  2025-01-02T03:19:44+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN        NaN        NaN
# ...

# %%
SS_london02
# Out:
#                           Type                       Date  \
# 0                Person search  2025-02-01T04:35:33+00:00
# 1                Person search  2025-02-01T14:24:45+00:00
# 2                Person search  2025-02-01T21:28:25+00:00
# 3                Person search  2025-02-01T21:35:37+00:00
# 4    Person and Vehicle search  2025-02-02T01:02:10+00:00
# ..                         ...                        ...
# 120              Person search  2025-02-28T18:45:46+00:00
# 121  Person and Vehicle search  2025-02-28T20:03:44+00:00
# 122              Person search  2025-02-28T21:25:07+00:00
# 123              Person search  2025-02-28T21:30:36+00:00
# 124              Person search  2025-02-28T22:12:07+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN  51.514267  -0.079838
# ...

# %%
SS_london03
# Out:
#                           Type                       Date  \
# 0                Person search  2025-03-01T21:45:31+00:00
# 1                Person search  2025-03-01T23:30:44+00:00
# 2    Person and Vehicle search  2025-03-02T15:11:20+00:00
# 3                Person search  2025-03-02T22:05:02+00:00
# 4    Person and Vehicle search  2025-03-03T18:29:41+00:00
# ..                         ...                        ...
# 136  Person and Vehicle search  2025-03-30T22:36:17+00:00
# 137  Person and Vehicle search  2025-03-31T01:14:01+00:00
# 138              Person search  2025-03-31T02:02:43+00:00
# 139  Person and Vehicle search  2025-03-31T22:10:40+00:00
# 140              Person search  2025-03-31T22:35:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN  51.517785  -0.079907
# 1                             NaN                 NaN  51.516869  -0.081113
# ...

# %%
SS_london123 = pd.concat([SS_london01,SS_london02,SS_london03])
SS_london123
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1    Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2    Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3    Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4                Person search  2025-01-02T03:19:44+00:00
# ..                         ...                        ...
# 136  Person and Vehicle search  2025-03-30T22:36:17+00:00
# 137  Person and Vehicle search  2025-03-31T01:14:01+00:00
# 138              Person search  2025-03-31T02:02:43+00:00
# 139  Person and Vehicle search  2025-03-31T22:10:40+00:00
# 140              Person search  2025-03-31T22:35:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN        NaN        NaN
# ...

# %% [markdown]
# ## เพิ่มแกน X (เพิ่ม Columns - เพิ่มรายละเอียดของข้อมูล)

# %%
street_london01 = pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-01/2025-01-city-of-london-street.csv')
outcome_london01 = pd.read_csv('/content/drive/MyDrive/Dataset_dpdm25/2025-01/2025-01-city-of-london-outcomes.csv')

# %%
street_london01.head()
# Out:
#                                             Crime ID    Month  \
# 0  8c7661d1b68d476454c5b68a58daee0d91781a94f60015...  2025-01
# 1  1b7fbc8deac5182e6b1e580ab4eb4ed520df688c3576bc...  2025-01
# 2  8476f32b188fae2d0d14b7db79e872fd7688f064e8ced3...  2025-01
# 3  92b8de6e45c3b711e802fb9d99e2a030c3f56b1c589e55...  2025-01
# 4  023587ed2c674a28bd52d6e03d505c3b0dba6d25e8b95b...  2025-01
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.107682  51.517786
# 1  City of London Police  City of London Police  -0.111596  51.518281
# 2  City of London Police  City of London Police  -0.097078  51.519045
# 3  City of London Police  City of London Police  -0.097290  51.521575
# 4  City of London Police  City of London Police  -0.098519  51.517332
#
#                     Location  LSOA code            LSOA name  \
# 0            On or near B521  E01000917          Camden 027C
# ...

# %%
outcome_london01.head()
# Out:
#                                             Crime ID    Month  \
# 0  040098831e60c233d8aa5b50d8ba0eb84b17a707e8d1b6...  2025-01
# 1  ec7d2ba71a794d65d2bfcb59a8c2d7c47fec751ef62cd5...  2025-01
# 2  80b1396383bd8a34a4d82b441fae8b1c3f5ad9629f98f0...  2025-01
# 3  8d38bee2faaeb65b554a5454c4d40ac9b02cfa11f0dd33...  2025-01
# 4  7d737142800c9976c115131cf7f8526d0c851f4dd11f31...  2025-01
#
#              Reported by           Falls within  Longitude  Latitude  \
# 0  City of London Police  City of London Police        NaN       NaN
# 1  City of London Police  City of London Police        NaN       NaN
# 2  City of London Police  City of London Police        NaN       NaN
# 3  City of London Police  City of London Police        NaN       NaN
# 4  City of London Police  City of London Police        NaN       NaN
#
#       Location LSOA code LSOA name  \
# 0  No location       NaN       NaN
# 1  No location       NaN       NaN
# 2  No location       NaN       NaN
# ...

# %% [markdown]
# ข้อมูล Streets เกิดก่อน Outcomes - จับจากถนน แล้วไปสืบสวน เป็นข้อมูล outcome

# %%
street_london01.shape
# Out:
# (629, 12)

# %%
outcome_london01.shape
# Out:
# (760, 10)

# %%
street_london01['Final Outcome'] = street_london01['Crime ID'].map(
                                  outcome_london01.set_index('Crime ID')['Outcome type'])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipython-input-774426286.py in <cell line: 0>()
# ----> 1 street_london01['Final Outcome'] = street_london01['Crime ID'].map(
#       2                                   outcome_london01.set_index('Crime ID')['Outcome type'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4698         dtype: object
#    4699         """
# -> 4700         new_values = self._map_values(arg, na_action=na_action)
#    4701         return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702             self, method="map"
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# ...

# %% [markdown]
# Error จาก ```.map()``` เกิดจาก index ในตารางรองมันซ้ำ ทำให้ไม่รู้ว่าจะเอาค่าจาก Row ไหนมาแปะ

# %%
outcome_london01_dedup = outcome_london01.drop_duplicates(keep='first', subset= 'Crime ID')
outcome_london01_dedup.shape
# Out:
# (751, 10)

# %%
street_london01['Final Outcome'] = street_london01['Crime ID'].map(
                                  outcome_london01_dedup.set_index('Crime ID')['Outcome type'])

# %%
street_london01.head()
# Out:
#                                             Crime ID    Month  \
# 0  8c7661d1b68d476454c5b68a58daee0d91781a94f60015...  2025-01
# 1  1b7fbc8deac5182e6b1e580ab4eb4ed520df688c3576bc...  2025-01
# 2  8476f32b188fae2d0d14b7db79e872fd7688f064e8ced3...  2025-01
# 3  92b8de6e45c3b711e802fb9d99e2a030c3f56b1c589e55...  2025-01
# 4  023587ed2c674a28bd52d6e03d505c3b0dba6d25e8b95b...  2025-01
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.107682  51.517786
# 1  City of London Police  City of London Police  -0.111596  51.518281
# 2  City of London Police  City of London Police  -0.097078  51.519045
# 3  City of London Police  City of London Police  -0.097290  51.521575
# 4  City of London Police  City of London Police  -0.098519  51.517332
#
#                     Location  LSOA code            LSOA name  \
# 0            On or near B521  E01000917          Camden 027C
# ...

# %%
street_london01.dropna(subset=['Final Outcome'])
# Out:
#                                               Crime ID    Month  \
# 4    023587ed2c674a28bd52d6e03d505c3b0dba6d25e8b95b...  2025-01
# 5    dffad61ad3005e323af26fbb3f3226c7ac2bddf8ccb252...  2025-01
# 6    e94f3cd0c64e59f43fc0556ce0a61ecb40805062e0517b...  2025-01
# 8    22874f5347d449c29240f4abeaa6a2aa4375a7b9bda444...  2025-01
# 11   f39615e054dd6ced4e7cac76acaaf0312429b67d1c944f...  2025-01
# ..                                                 ...      ...
# 606  a2e385a184df186470d5dbf8278321f1a8f7a064984c29...  2025-01
# 608  d9e4932fa33ac1e01da801a7e8ed8834a858a1467791cc...  2025-01
# 614  cbec096552b16212534d114dd9af714ddaa7e8b8a7b7a0...  2025-01
# 615  6a5130a3b6adce896bd954f21764bd25284a2d9dbed6dd...  2025-01
# 621  56becc974138ba73925aa8c7e8a011845825f78fc36ff1...  2025-01
#
#                Reported by           Falls within  Longitude   Latitude  \
# 4    City of London Police  City of London Police  -0.098519  51.517332
# ...

# %% [markdown]
# # Save ตาราง

# %%
street_london01.dropna(subset=['Final Outcome']).to_csv('street_london1_outcome.csv')

# %% [markdown]
# # สร้างตารางใหม่

# %% [markdown]
# ![pandas-dataframe-shadow.png](data:image/png;base64,...)

# %% [markdown]
# # Basic Visualization

# %%
pd.plotting.scatter_matrix((street_london01.dropna(subset=['Final Outcome']))[['Longitude','Latitude']]);

# %%
onlynumber = street_london01.dropna(subset=['Final Outcome'])[['Longitude','Latitude','Crime type']]

# %%
onlynumber
# Out:
#      Longitude   Latitude                    Crime type
# 4    -0.098519  51.517332                   Other theft
# 5    -0.098519  51.517332                  Public order
# 6    -0.097245  51.515387                   Shoplifting
# 8    -0.097144  51.515062         Theft from the person
# 11   -0.092488  51.520598                 Bicycle theft
# ..         ...        ...                           ...
# 606        NaN        NaN         Theft from the person
# 608        NaN        NaN  Violence and sexual offences
# 614        NaN        NaN  Violence and sexual offences
# 615        NaN        NaN  Violence and sexual offences
# 621        NaN        NaN  Violence and sexual offences
#
# [275 rows x 3 columns]

# %%
onlynumber['Longitude'] = onlynumber['Longitude']*10
onlynumber['Latitude'] = onlynumber['Latitude']-51

# %%
onlynumber
# Out:
#      Longitude  Latitude                    Crime type
# 4     -492.595  -492.595                   Other theft
# 5     -492.595  -492.595                  Public order
# 6     -486.225  -486.225                   Shoplifting
# 8     -485.720  -485.720         Theft from the person
# 11    -462.440  -462.440                 Bicycle theft
# ..         ...       ...                           ...
# 606        NaN       NaN         Theft from the person
# 608        NaN       NaN  Violence and sexual offences
# 614        NaN       NaN  Violence and sexual offences
# 615        NaN       NaN  Violence and sexual offences
# 621        NaN       NaN  Violence and sexual offences
#
# [275 rows x 3 columns]

# %%
pd.plotting.parallel_coordinates(onlynumber.head(5), 'Crime type');
